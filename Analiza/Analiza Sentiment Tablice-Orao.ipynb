# %% [markdown]
# # Analiza Sentiment leksikona -GTP2-Orao

# %%
import pandas as pd

# %%
RES_DIR = "..\\resources\\"
MOD_DIR = "..\\ml_models\\"

# %% [markdown]
# Odve se učitava leksikon. Svi leksikoni su snimljeni us dva falja. Falj sa _a ima i vrste reči radi analize.

# %%
sent_an = pd.read_csv(RES_DIR + "srbsentiwordnet_a6.csv",  index_col=0)

# %%
sent_an["OBJ"] = 1-( sent_an["NEG"]+sent_an["POS"])

# %%
sent_an
# Out:
#                            POS       NEG  \
# ID
# ENG30-03574555-n  1.788111e-07  0.000006
# ENG30-07810907-n  1.430480e-06  0.000007
# ENG30-00721431-n  1.281200e-06  0.000075
# ENG30-00473799-v  4.470226e-07  0.000011
# ENG30-00903385-v  3.099366e-06  0.000023
# ...                        ...       ...
# ENG30-15266265-n  8.939860e-07  0.000035
# ENG30-15266685-n  2.682106e-07  0.000013
# ENG30-15266911-n  9.238161e-07  0.000024
# ENG30-15276642-n  2.086144e-07  0.000004
# ENG30-15291498-n  3.576058e-07  0.000019
#
#                                                            Lemme  \
# ID
# ENG30-03574555-n                                        ustanova
# ENG30-07810907-n                                           začin
# ENG30-00721431-n                                           mesto
# ENG30-00473799-v            obnoviti,doterati,uglancati,uljuditi
# ENG30-00903385-v                                       oprostiti
# ...                                                          ...
# ENG30-15266265-n                                          mandat
# ENG30-15266685-n                                         sredina
# ENG30-15266911-n  gotovo,konac,kraj,prestanak,svršetak,završetak
# ENG30-15276642-n                            b/s,bitova u sekundi
# ENG30-15291498-n                                          mandat
#
#                                                          Definicija Vrsta  \
# ID
# ENG30-03574555-n  zgrada u kojoj se nalazi organizaciona jedinic...     n
# ENG30-07810907-n     pripremljeni dodatak jelu za poboljšanje ukusa     n
# ENG30-00721431-n                  u nečijim prilikama, mogućnostima     n
# ENG30-00473799-v  Ostalo je još samo da se doteraju neke finese ...     v
# ENG30-00903385-v  Zapad mu je oprostio što se nekada računao u S...     v
# ...                                                             ...   ...
# ENG30-15266265-n                                 mandat predsednika     n
# ENG30-15266685-n    vreme između početka i kraja vremenskog perioda     n
# ENG30-15266911-n             tačka u vremenu kada se nešto završava     n
# ENG30-15276642-n  (računarstvo) brzina prenosa podataka (npr. ko...     n
# ENG30-15291498-n      mandast tokom kojeg se drži određena pozicija     n
#
#                        OBJ
# ID
# ENG30-03574555-n  0.999994
# ENG30-07810907-n  0.999991
# ENG30-00721431-n  0.999924
# ENG30-00473799-v  0.999989
# ENG30-00903385-v  0.999974
# ...                    ...
# ENG30-15266265-n  0.999964
# ENG30-15266685-n  0.999987
# ENG30-15266911-n  0.999975
# ENG30-15276642-n  0.999996
# ENG30-15291498-n  0.999980
#
# [25320 rows x 6 columns]

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Statistike

# %%
# Define bin edges
bin_edges = [i/8 for i in range(9)]
bin_labels = [f"[{bin_edges[i]}, {bin_edges[i+1]})" for i in range(len(bin_edges)-1)]

# Function to bin data and get both count and percentage for each bin
def bin_data(column):
    binned_data = pd.cut(column, bins=bin_edges, labels=bin_labels, include_lowest=True, right=False)
    counts = binned_data.value_counts().sort_index()
    percentages = (counts / counts.sum()) * 100
    return pd.DataFrame({'Count': counts, 'Percentage': percentages})

# Apply the function to each column and store results in a dictionary
results = {
    'OBJ': bin_data(sent_an['OBJ']),
    'POS': bin_data(sent_an['POS']),
    'NEG': bin_data(sent_an['NEG'])
}

results
# Out:
# {'OBJ':                Count  Percentage
#  OBJ
#  [0.0, 0.125)     158    0.624013
#  [0.125, 0.25)     93    0.367299
#  [0.25, 0.375)    259    1.022907
#  [0.375, 0.5)     209    0.825434
#  [0.5, 0.625)     328    1.295419
#  [0.625, 0.75)    522    2.061611
#  [0.75, 0.875)    526    2.077409
#  [0.875, 1.0)   23225   91.725908,
#  'POS':                Count  Percentage
#  POS
#  [0.0, 0.125)   24412   96.413902
#  [0.125, 0.25)    215    0.849131
#  [0.25, 0.375)    364    1.437599
#  [0.375, 0.5)     116    0.458136
#  [0.5, 0.625)      86    0.339652
#  [0.625, 0.75)     72    0.284360
#  [0.75, 0.875)     27    0.106635
#  [0.875, 1.0)      28    0.110585,
#  'NEG':                Count  Percentage
#  NEG
#  [0.0, 0.125)   23912   94.439179
#  [0.125, 0.25)    593    2.342022
#  [0.25, 0.375)    200    0.789889
#  [0.375, 0.5)     234    0.924171
#  [0.5, 0.625)      83    0.327804
#  [0.625, 0.75)    156    0.616114
#  [0.75, 0.875)     44    0.173776
#  [0.875, 1.0)      98    0.387046}

# %%
sent_an[sent_an["POS"]>.9][["Lemme", "POS"]]
# Out:
#                                                               Lemme       POS
# ID
# ENG30-06206800-n                                 poštovanje,respekt  0.999840
# ENG30-00860620-v            slaviti,veličati,glorifikovati,uzdizati  0.999931
# ENG30-01148283-a                                             srećan  0.998293
# ENG30-04616916-n                                           karakter  0.930308
# ENG30-02360448-a                                 podložan,prijemčiv  0.999797
# ENG30-02646757-v                                   osigurati,kupiti  0.955058
# ENG30-02356567-v                                 setiti se,pomenuti  0.998486
# ENG30-01372049-a                                           ljubazan  0.996126
# ENG30-01778568-v                          strahopoštovati,uvažavati  0.930115
# ENG30-07500414-n                             naklonost,naklonjenost  0.950136
# ENG30-07545415-n                                   obzir,poštovanje  0.999924
# ENG30-01775535-v                                             voleti  0.999866
# ENG30-07527061-n                                           ?bonheur  0.999156
# ENG30-07544129-n                                   žar,oduševljenje  0.999827
# ENG30-00921538-a                                 zanosno,uzbuđujuće  0.998935
# ENG30-07501420-n                                         obožavanje  0.999892
# ENG30-01813668-v  hodati po oblacima,biti na devetom nebu,skakat...  0.999720
# ENG30-07531713-n                                   samozadovoljstvo  0.998497
# ENG30-07544213-n                                      zaljubljenost  0.999842
# ENG30-02679012-v                       zadovoljiti,kvalifikovati se  0.999328
# ENG30-07510184-n                                   strahopoštovanje  0.999893
# ENG30-00183090-b  predivno,čudesno,sjajno,izvrsno,vrhunski,velič...  0.998491
# ENG30-00363031-a                                    nasmejan,ozaren  0.999879
# ENG30-00017782-a                                        prihvatljiv  0.905454
# ENG30-05142180-n                       dobro,dobrota,ispravno,pravo  0.999544

# %%
(sent_an["POS"]>.9).sum()
# Out:
# 25

# %% [markdown]
# Raspored reči prema negativnom polaritetu

# %%
sent_an[sent_an["NEG"]>.9][["Lemme", "NEG"]]
# Out:
#                                                  Lemme       NEG
# ID
# ENG30-01566705-v                      smrskati,skršiti  0.935953
# ENG30-07510625-n                                   šok  0.997538
# ENG30-01779165-v      uplašiti,prestrašiti,prestraviti  0.999801
# ENG30-05160173-n                    trulost,nagnjilost  0.939346
# ENG30-07537485-n                             depresija  0.995920
# ENG30-02451951-a                          nepopustljiv  0.999925
# ENG30-01790020-v      potresti,obeshrabriti,zaljuljati  0.999692
# ENG30-07289014-n                       nevolja,teškoća  0.999651
# ENG30-13265011-n                            dar,poklon  0.986479
# ENG30-00567593-a                             nepovezan  0.999358
# ENG30-13989051-n                         jad,tugovanje  0.999841
# ENG30-01752167-a                             nesavršen  0.999967
# ENG30-13980288-n                           antagonizam  0.996161
# ENG30-07553301-n                           razumevanje  0.937257
# ENG30-05204637-n                          nesposobnost  0.999674
# ENG30-00835609-a                            neefikasan  0.999776
# ENG30-01792567-v                     nauditi,naškoditi  0.905287
# ENG30-01799794-v   poniziti,ojaditi,osramotiti,uniziti  0.999718
# ENG30-07535010-n                         skrhanost,bol  0.999867
# ENG30-14285662-n                        povreda,ozleda  0.998775
# ENG30-00066191-v                               plakati  0.999686
# ENG30-02575082-v                      varati,podvaliti  0.991357
# ENG30-01153548-n                        diskriminacija  0.999944
# ENG30-07314427-n               nezgoda,nesretan slučaj  0.999863
# ENG30-01246697-n                    teroristički napad  0.996007
# ENG30-02085132-a                  nenaučan,neznanstven  0.999331
# ENG30-14539268-n                            bezbednost  0.999238
# ENG30-14526764-n                nepodložnost,otpornost  0.999908
# ENG30-14530061-n                            podložnost  0.997828
# ENG30-14541044-n                              opasnost  0.999950
# ENG30-14441230-n                             nečasnost  0.989279
# ENG30-07301336-n                               nesreća  0.998446
# ENG30-05204982-n                          bespomoćnost  0.996596
# ENG30-05139094-n                       mana,nedostatak  0.999878
# ENG30-02135913-a                              bespolni  0.990936
# ENG30-01373728-a                            neljubazan  0.996272
# ENG30-04801168-n                        neoriginalnost  0.999869
# ENG30-01691073-a                          nepravoveran  0.995753
# ENG30-04664964-n                         nebrižljivost  0.999927
# ENG30-01161087-v                              rasipati  0.999344
# ENG30-04629194-n                       neemocionalnost  0.945726
# ENG30-13988663-n                               nesreća  0.989018
# ENG30-00064095-v             olakšati,ublažiti,utažiti  0.902575
# ENG30-01564144-v                  uništiti,upropastiti  0.999617
# ENG30-01727926-a                                prošli  0.992551
# ENG30-01064286-a                            neslobodan  0.997215
# ENG30-00789871-a                               crvolik  0.999505
# ENG30-00973077-n         rat,vojna,vojevanje,ratovanje  0.999892
# ENG30-01595596-a                  nenormalan,anormalan  0.999499
# ENG30-02566015-a                 neraspoložen,nevoljan  0.999608
# ENG30-01244410-a                        neprijateljski  0.980214
# ENG30-01808769-v                       odbijati,odbiti  0.999874
# ENG30-01625063-a                 mrzak,bestidan,oduran  0.999787
# ENG30-07505347-n                          saosećajnost  0.974133
# ENG30-07546125-n                              brižnost  0.999413
# ENG30-07547805-n                         netrpeljivost  0.987974
# ENG30-00228910-b                   stidljivo,plašljivo  0.997931
# ENG30-00252498-a                              plašljiv  0.965157
# ENG30-01158020-a                       okoreo,bezdušan  0.989790
# ENG30-01780729-v                            plašiti se  0.997432
# ENG30-00822907-a                              teskoban  0.999869
# ENG30-01625893-a       gadan,otužan,neprijatan,odbojan  0.999942
# ENG30-00193799-a  strašan,strahovit,užasan,užasavajući  0.999898
# ENG30-00079786-a                               užasnut  0.965015
# ENG30-00252733-a                              zaplašen  0.989447
# ENG30-00079262-a                    zlostavljan,kinjen  0.991465
# ENG30-01626562-a                       odvratan,gnusan  0.999856
# ENG30-01805064-a                            neprijatan  0.999966
# ENG30-01813393-v                          rastužiti se  0.993586
# ENG30-01362684-a                          melanholičan  0.998847
# ENG30-07532832-n                               setnost  0.999881
# ENG30-07535430-n                              tuxznost  0.999735
# ENG30-07537068-n                            neveselost  0.999744
# ENG30-07533097-n                           melanholija  0.999356
# ENG30-01365544-a                   skrhan,srceparajući  0.999926
# ENG30-02347086-a               bedan,kukavan,oplačljiv  0.999532
# ENG30-01364008-a                              žalostan  0.999801
# ENG30-00404501-b                                 tužno  0.999675
# ENG30-00343250-b                             napušteno  0.999581
# ENG30-01743217-a                               pokajan  0.930953
# ENG30-07534108-n               napuštenost,usamljenost  0.999821
# ENG30-07536245-n              krivica,osećanje krivice  0.999011
# ENG30-01150205-a                               mizeran  0.999966
# ENG30-01362387-a                               žaloban  0.999607
# ENG30-01366157-a                             ožalošćen  0.999421
# ENG30-00725772-a                               zavisan  0.999940
# ENG30-00781644-a                                 mutan  0.999730
# ENG30-01956523-a                           neotklonjiv  0.997795
# ENG30-00735336-a                       izgoreo,sagoreo  0.990864
# ENG30-01986349-a                    ograničen,uskogrud  0.999540
# ENG30-01345307-a                       dosadan,zamoran  0.993515
# ENG30-00220409-n                     ubistvo iz nehata  0.999853
# ENG30-00744758-n                    maltretman,mučenje  0.996830
# ENG30-00856860-a                    rezervisan,zadržan  0.999790
# ENG30-01249816-n                huliganstvo,vandalizam  0.971215
# ENG30-04834605-n                             sebičnost  0.999640

# %%
(sent_an["NEG"]>.9).sum()
# Out:
# 96

# %% [markdown]
# Raspored reči prema objektivnosti

# %%
# Define bin edges
bin_edges = [i/8 for i in range(9)]
bin_labels = [f"[{bin_edges[i]}, {bin_edges[i+1]})" for i in range(len(bin_edges)-1)]

# Function to bin data and get both count and percentage for each bin
def bin_data(column):
    binned_data = pd.cut(column, bins=bin_edges, labels=bin_labels, include_lowest=True, right=False)
    counts = binned_data.value_counts().sort_index()
    percentages = (counts / counts.sum()) * 100
    return pd.DataFrame({'Count': counts, 'Percentage': percentages})

# Apply the function to each column and store results in a dictionary
results = {
    'OBJ': bin_data(sent_an['OBJ']),
    'POS': bin_data(sent_an['POS']),
    'NEG': bin_data(sent_an['NEG'])
}

results
# Out:
# {'OBJ':                Count  Percentage
#  OBJ
#  [0.0, 0.125)     158    0.624013
#  [0.125, 0.25)     93    0.367299
#  [0.25, 0.375)    259    1.022907
#  [0.375, 0.5)     209    0.825434
#  [0.5, 0.625)     328    1.295419
#  [0.625, 0.75)    522    2.061611
#  [0.75, 0.875)    526    2.077409
#  [0.875, 1.0)   23225   91.725908,
#  'POS':                Count  Percentage
#  POS
#  [0.0, 0.125)   24412   96.413902
#  [0.125, 0.25)    215    0.849131
#  [0.25, 0.375)    364    1.437599
#  [0.375, 0.5)     116    0.458136
#  [0.5, 0.625)      86    0.339652
#  [0.625, 0.75)     72    0.284360
#  [0.75, 0.875)     27    0.106635
#  [0.875, 1.0)      28    0.110585,
#  'NEG':                Count  Percentage
#  NEG
#  [0.0, 0.125)   23912   94.439179
#  [0.125, 0.25)    593    2.342022
#  [0.25, 0.375)    200    0.789889
#  [0.375, 0.5)     234    0.924171
#  [0.5, 0.625)      83    0.327804
#  [0.625, 0.75)    156    0.616114
#  [0.75, 0.875)     44    0.173776
#  [0.875, 1.0)      98    0.387046}

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Histogrami

# %% [markdown]
# ### Celog leksikona

# %%
sent_an.hist(bins=8)
# Out:
# array([[<Axes: title={'center': 'POS'}>, <Axes: title={'center': 'NEG'}>],
#        [<Axes: title={'center': 'OBJ'}>, <Axes: >]], dtype=object)

# %%
sent_an[sent_an["POS"]>.1]["POS"].hist(bins=8)
# Out:
# <Axes: >

# %%
sent_an[sent_an["POS"]>.2]["POS"].hist(bins=8)
# Out:
# <Axes: >

# %%
sent_an[sent_an["NEG"]>.1]["NEG"].hist(bins=8)
# Out:
# <Axes: >

# %%
sent_an[sent_an["NEG"]>.2]["NEG"].hist(bins=8)
# Out:
# <Axes: >

# %% [markdown]
# ### Po Vrsti
# a - pridev <br>
# v - glagol <br>
# n - imenica <br>

# %%
sent_an["Vrsta"].value_counts(sort=True)
# Out:
# Vrsta
# n    20080
# v     2896
# a     2202
# b      142
# Name: count, dtype: int64

# %%
sent_an["Vrsta"].value_counts(sort=True).plot(kind ="pie")
# Out:
# <Axes: ylabel='count'>

# %%
sent_an.hist(bins=8, by="Vrsta", legend =True, column= ["POS", "NEG"] )
# Out:
# array([[<Axes: title={'center': 'a'}>, <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'n'}>, <Axes: title={'center': 'v'}>]],
#       dtype=object)

# %%
sent_an[sent_an["POS"]>.1].hist(bins=8, by="Vrsta", column="POS")
# Out:
# array([[<Axes: title={'center': 'a'}>, <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'n'}>, <Axes: title={'center': 'v'}>]],
#       dtype=object)

# %%
sent_an[sent_an["POS"]>.2].hist(bins=8, by="Vrsta", column="POS")
# Out:
# array([[<Axes: title={'center': 'a'}>, <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'n'}>, <Axes: title={'center': 'v'}>]],
#       dtype=object)

# %%
sent_an[sent_an["NEG"]>.1].hist(bins=8, by="Vrsta", column="NEG")
# Out:
# array([[<Axes: title={'center': 'a'}>, <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'n'}>, <Axes: title={'center': 'v'}>]],
#       dtype=object)

# %%
sent_an[sent_an["NEG"]>.2].hist(bins=8, by="Vrsta", column="NEG")
# Out:
# array([[<Axes: title={'center': 'a'}>, <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'n'}>, <Axes: title={'center': 'v'}>]],
#       dtype=object)

# %% [markdown]
# Ovde se prikazuje raspored vresnosti u odnsu na oba polariteta, ali bez vrednosti (0,0) zbog preglednosti

# %%
import numpy as np
import matplotlib.pyplot as plt

sent_bez0 = sent_an[np.logical_xor(((sent_an["POS"] ==0) & (sent_an["NEG"] == 0)), 1)]

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
x, y = sent_bez0["POS"], sent_bez0["NEG"]
hist, xedges, yedges = np.histogram2d(x, y, bins=64, range=[[0, 1], [0, 1]])

# Construct arrays for the anchor positions of the 16 bars.
xpos, ypos = np.meshgrid(xedges[:-1] , yedges[:-1] , indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

# Construct arrays with the dimensions for the 64 bars.
dx = dy = 0.125 * np.ones_like(zpos)
dz = hist.ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')

plt.show()

# %%
((sent_an["POS"] ==0) & (sent_an["NEG"] == 0)).value_counts(sort=True).plot(kind ="pie")
# Out:
# <Axes: ylabel='count'>

# %%
# srbsentiwordnet2.cvs
# srbsentiwordnet_a2.cvs
